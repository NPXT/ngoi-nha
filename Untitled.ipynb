# %%
import turtle
screen=turtle.Screen()
cua= turtle.Turtle()
cua.pensize(3)
cua.pencolor("blue")
for i in range (2):
    cua.forward(40)
    cua.left(90)
    cua.forward(50)
    cua.left(90)
than=turtle.Turtle()
than.pensize(3)
than.pencolor("blue")
than.penup()
than.goto(-50,0)
than.pendown()
for i in range (2):
    than.forward(180)
    than.left(90)
    than.forward(90)
    than.left(90)
mai=turtle.Turtle()
mai.pensize(3)
mai.pencolor("blue")
mai.penup()
mai.goto(-50,90)
mai.pendown()
mai.forward(115)
mai.left(130)
mai.forward(90)
mai.left(100)
mai.forward(90)
ongkhoi=turtle.Turtle()
ongkhoi.pensize(3)
ongkhoi.pencolor("blue")
ongkhoi.penup()
ongkhoi.goto(45,115)
ongkhoi.pendown()
ongkhoi.left(90)
ongkhoi.forward(30)
ongkhoi.left(90)
ongkhoi.forward(15)
ongkhoi.left(90)
ongkhoi.forward(20)
khoi1=turtle.Turtle()
khoi1.pensize(3)
khoi1.pencolor("blue")
khoi1.penup()
khoi1.goto(45,155)
khoi1.pendown()
khoi1.left(90)
khoi1.forward(35)
khoi2=turtle.Turtle()
khoi2.pensize(3)
khoi2.pencolor("blue")
khoi2.penup()
khoi2.goto(40,160)
khoi2.pendown()
khoi2.left(90)
khoi2.forward(25)
turtle.done()
